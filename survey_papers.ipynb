# %%
import paper_dataset

# %%
with open("survey_papers.txt") as f:
    lines = f.readlines()
    manual_selection = [i for i, l in enumerate(lines) if l.startswith('+')]
print("Selected:", len(manual_selection))
print(manual_selection)
# Out:
# Selected: 11
# [1, 2, 3, 4, 7, 13, 16, 23, 24, 28, 50]

# %%
df = paper_dataset.load("data/survey_papers.json")

# %%
for row in df.iloc[manual_selection].iloc:
    paper_dataset.print_sample(row)
